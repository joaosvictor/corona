# %% [markdown]
# ### After voice assistant, comes the analisys of corona(covid-19)
#  - plot all the data of US, the leader of the rank
#  - result it with numpy and pandas
#  - final conclusion with the graph

# %%
# https://ourworldindata.org/coronavirus-source-data
# https://en.wikipedia.org/wiki/Coronavirus
# It's a real analisys of corona. 
# date of code: August/04/2020.
# %pylab inline
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import seaborn as sb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Joao\miniconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['show', 'mean']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
data = pd.read_csv('bigdata.csv')
data.columns
data
# Out:
#       iso_code      continent       location       date  total_cases  \
# 0          ABW  North America          Aruba  3/13/2020          2.0
# 1          ABW  North America          Aruba  3/20/2020          4.0
# 2          ABW  North America          Aruba  3/24/2020         12.0
# 3          ABW  North America          Aruba  3/25/2020         17.0
# 4          ABW  North America          Aruba  3/26/2020         19.0
# ...        ...            ...            ...        ...          ...
# 34658      NaN            NaN  International  2/28/2020        705.0
# 34659      NaN            NaN  International  2/29/2020        705.0
# 34660      NaN            NaN  International   3/1/2020        705.0
# 34661      NaN            NaN  International   3/2/2020        705.0
# 34662      NaN            NaN  International  3/10/2020        696.0
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0            2.0           0.0         0.0                   18.733
# ...

# %%
data.mean()
# Out:
# total_cases                        5.518239e+04
# new_cases                          1.064247e+03
# total_deaths                       2.796460e+03
# new_deaths                         4.042457e+01
# total_cases_per_million            1.169933e+03
# new_cases_per_million              1.833735e+01
# total_deaths_per_million           4.257603e+01
# new_deaths_per_million             5.378441e-01
# new_tests                          1.733729e+04
# total_tests                        8.582183e+05
# total_tests_per_thousand           3.461002e+01
# new_tests_per_thousand             6.074436e-01
# new_tests_smoothed                 1.645514e+04
# new_tests_smoothed_per_thousand    5.783100e-01
# tests_per_case                     2.077904e+02
# positive_rate                      6.263272e-02
# stringency_index                   5.820674e+01
# population                         9.372524e+07
# population_density                 3.630009e+02
# median_age                         3.158908e+01
# ...

# %%
x = np.array(meanPlot.total_deaths)
x.reshape(1, -1)
# Out:
# array([[0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 1.00000e+00, 2.00000e+00, 6.00000e+00, 9.00000e+00,
# ...

# %%
y = np.array(meanPlot.total_deaths)
y.reshape(1, -1)
# Out:
# array([[0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 1.00000e+00, 2.00000e+00, 6.00000e+00, 9.00000e+00,
# ...

# %%
# ranking country 'United States','Brazil','India','Russia','South Africa'
meanPlot = data[data.location =='United States']
meanPlot2 = data[data.location == 'Brazil']
plt.plot(meanPlot.total_deaths,color='navy')
plt.plot(meanPlot2.total_deaths,color='red')
plt.legend(['US','Brazil'])
plt.title('Total deaths')
plt.grid(True)
plt.show() # total death graph

# %%
# start total case 
x = np.array(meanPlot.total_cases)
x.reshape(1, -1)
# Out:
# array([[0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00, 1.000000e+00, 1.000000e+00,
#         1.000000e+00, 2.000000e+00, 2.000000e+00, 5.000000e+00,
#         5.000000e+00, 5.000000e+00, 5.000000e+00, 6.000000e+00,
#         7.000000e+00, 8.000000e+00, 1.100000e+01, 1.100000e+01,
#         1.100000e+01, 1.200000e+01, 1.200000e+01, 1.200000e+01,
#         1.200000e+01, 1.200000e+01, 1.300000e+01, 1.300000e+01,
#         1.400000e+01, 1.500000e+01, 1.500000e+01, 1.500000e+01,
#         1.500000e+01, 1.500000e+01, 1.500000e+01, 1.500000e+01,
#         1.600000e+01, 3.500000e+01, 3.500000e+01, 3.500000e+01,
#         5.300000e+01, 5.300000e+01, 5.900000e+01, 6.000000e+01,
# ...

# %%
y = np.array(meanPlot2.total_cases)
y.reshape(1, -1)
# Out:
# array([[0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00, 1.000000e+00, 1.000000e+00,
# ...

# %%
meanPlot = data[data.location =='United States']
meanPlot2 = data[data.location == 'Brazil']
plt.plot(meanPlot.total_cases,color='navy')
plt.plot(meanPlot2.total_cases,color='red')
plt.legend(['US','Brazil'])
plt.ylabel('Numbers in millions.')
plt.title('Total cases')
plt.grid(True)
plt.show()
# just plotting to take a idea

# %%
data.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  3.432200e+04   34322.000000   34322.000000  34322.000000
# mean   5.518239e+04    1064.246955    2796.460055     40.424567
# std    5.639558e+05    9851.093520   26478.239669    350.200664
# min    0.000000e+00   -2461.000000       0.000000  -1918.000000
# 25%    2.300000e+01       0.000000       0.000000      0.000000
# 50%    5.020000e+02       6.000000       9.000000      0.000000
# 75%    5.720750e+03     109.000000     114.000000      2.000000
# max    1.826354e+07  298082.000000  693726.000000  10504.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             34258.000000           34258.000000
# mean               1169.932888              18.337345
# std                2791.538282              62.841388
# min                   0.000000            -265.189000
# 25%                   9.867500               0.000000
# 50%                 174.473000               0.850000
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# define one new instance
Xnew = [[2.750318, 4.713562]]
# make a prediction
ynew = model.predict(Xnew)
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[2.750318, 4.713562], Predicted=0

# %%
br = 2.750318
us = 4.713562# 2m plus
show =[]
while us > br:
    mean = us + br // 2
    print(mean) # 5.71
    break
# Out:
# 5.713562

# %%
sb.pairplot(meanPlot)#take a look in the US, the leader at the rank
